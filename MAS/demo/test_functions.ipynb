# %%
from mas_skipper.core import roi_shifting
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from mas_skipper.core import roi_shifting
#
# ModuleNotFoundError: No module named 'mas_skipper'

# %%
from
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ..mas_skipper import best_gain_fit_fast
#
# ImportError: attempted relative import with no known parent package

# %%
from mas_skipper import create_report_pdf, roi_shifting
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from mas_skipper import create_report_pdf, roi_shifting
#
# ModuleNotFoundError: No module named 'mas_skipper'

# %%
pwd
# Out:
# '/home/allon/Escritorio/new_ptcs/MAS/demo'

# %%
from ..mas_skipper.core.core import best_gain_fit_fast
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from ..mas_skipper.core.core import best_gain_fit_fast
#
# ImportError: attempted relative import with no known parent package
